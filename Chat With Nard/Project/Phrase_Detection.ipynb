# %%
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import joblib

# %%
# Reading data
train_data = pd.read_csv('../data/training_data.tsv',header=0,delimiter="\t" ,quoting=3)

# %%
# Function to define if there is reminder 
def found(x):
    if (x[0] == "Not Found"):
        return "Not Found"
    else:
        return "Found"

# %%
#Applying the found function
train_data['label_found'] = train_data[['label']].apply( found , axis = 1)

# %%
#This Function help us to remove the Digits and Emojis from the data
def clean_txt(texts):
    letters = re.sub("[^a-zA-Z]",' ', str(texts))
    lower_case = letters.lower()
    words = lower_case.split()
    stopword = stopwords.words('english')
    meaning_words = [w for w in words if not w in stopword]
    return (" ".join(meaning_words))

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\JOY
# [nltk_data]     SINHA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
#remove the Digits and Emojis from the data
train_data['sent_clean'] = [clean_txt(review) for review in train_data["sent"].values]

# %%
#Loading test data as test_data
test_data = pd.read_csv('../data/eval_data.txt',header=0,delimiter="\t" ,quoting=3)

# %%
#remove the Digits and Emojis from the data
test_data['sent_clean'] = [clean_txt(review) for review in test_data["sent"].values]

# %%
#Show the Data
test_data.sample(10)
# Out:
#                                                   sent  \
# 93                               Can you set me alarms
# 815                    Please schedule it for everyday
# 81   Can you please remind me for a vaccination at ...
# 939  I need 2 calls one fr 7.00 am n another for 7....
# 763  Surely,Thanks. The same will be for the Langua...
# 428  Can you remind me to send quote for incastt ma...
# 665                          Please close the reminder
# 327                         Remind me at 2:42 pm today
# 389               i would like this reminder every day
# 494         Remind me to take a cake home at 7pm today
#
#                              sent_clean
# 93                           set alarms
# 815            please schedule everyday
# 81         please remind vaccination pm
# 939         need calls one fr n another
# 763     surely thanks language reminder
# 428  remind send quote incastt machines
# 665               please close reminder
# 327                     remind pm today
# 389       would like reminder every day
# 494      remind take cake home pm today

# %%
#Convert a collection of text documents to a matrix of token counts
#Bow train
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, max_features = 12000) 
bow_train = (vectorizer.fit_transform(train_data['sent_clean'])).toarray()
bow_test = (vectorizer.transform(test_data['sent_clean'])).toarray()

# %%
#Showing Data
train_data.sample(30)
# Out:
#                                                    sent  \
# 2659                   Remind me today at 7:00 also ok?
# 6919           You need to remind me from 6 am to 10 pm
# 9026                             Reminder for shaving ?
# 7867                            About meeting boss at 9
# 6161                                  Set me a reminder
# 7929                       Thank you for your remainder
# 1901          Can i have it scheduled on every weekday?
# 6994    Can you set reminder at 10:00 am for Wipro work
# 393                          Thanx for reminder swapnil
# 2889  Can you tell me a software for windows laptop ...
# 1837                       Can you call me 2 or 3 times
# 5156  Wish Birthday Name: Anniversary Date: December...
# 8708                   Can you please remind me at 7:20
# 675   Remind me every Monday,Wednesday and friday to...
# 512                Please deactivate the above reminder
# 5590                            Thanq for you reminders
# 3151                             Sry call me at 10.30am
# 3244                          Which remainder is this ?
# 8532                              What about after 8pm?
# 1327  Pls remind me for job healthcare for tomorrow ...
# 4139                      Please reminder me at 1.40 pm
# 837                       Thanks a lot for the reminder
# 6927  Can you remind me to book a tatkal ticket tomo...
# 5172  Nd i want remainders after every 2 hrs...as to...
# 6574  Plz remind at 10am tmrw tht i have to consult ...
# 3574  Today Remind me to remind bhagyashree about he...
# 151   Please remind me about sql paper checking arou...
# 8381                                Remind after 1 hour
# 1551  Remind me to check with my bank for my loans, ...
# 1971                              Thanks fr ur reminder
#
#                                                   label label_found  \
# 2659                                          Not Found   Not Found
# 6919                                          Not Found   Not Found
# 9026                                            shaving       Found
# 7867                                       meeting boss       Found
# 6161                                          Not Found   Not Found
# 7929                                          Not Found   Not Found
# 1901                                          Not Found   Not Found
# 6994                                         Wipro work       Found
# 393                                           Not Found   Not Found
# 2889                                          Not Found   Not Found
# 1837                                          Not Found   Not Found
# 5156                                          Not Found   Not Found
# 8708                                          Not Found   Not Found
# 675                                         potato peel       Found
# 512                                           Not Found   Not Found
# 5590                                      you reminders       Found
# 3151                                          Not Found   Not Found
# 3244                                          Not Found   Not Found
# 8532                                          Not Found   Not Found
# 1327                                     job healthcare       Found
# 4139                                          Not Found   Not Found
# 837                                           Not Found   Not Found
# 6927                               book a tatkal ticket       Found
# 5172                               Nd i want remainders       Found
# 6574                    consult a case wth periodontist       Found
# 3574  remind bhagyashree about her friends stay in pune       Found
# 151                      sql paper checking around 11am       Found
# 8381                                          Not Found   Not Found
# 1551  check with my bank for my loans and phone and ...       Found
# 1971                                          Not Found   Not Found
#
#                                              sent_clean
# 2659                               remind today also ok
# 6919                                     need remind pm
# 9026                                   reminder shaving
# 7867                                       meeting boss
# 6161                                       set reminder
# 7929                                    thank remainder
# 1901                            scheduled every weekday
# 6994                            set reminder wipro work
# 393                              thanx reminder swapnil
# 2889  tell software windows laptop following feature...
# 1837                                         call times
# 5156  wish birthday name anniversary date december time
# 8708                                      please remind
# 675    remind every monday wednesday friday potato peel
# 512                          please deactivate reminder
# 5590                                    thanq reminders
# 3151                                           sry call
# 3244                                          remainder
# 8532                                                 pm
# 1327              pls remind job healthcare tomorrow pm
# 4139                                 please reminder pm
# 837                                 thanks lot reminder
# 6927         remind book tatkal ticket tomorrow morning
# 5172       nd want remainders every hrs tommorrow paper
# 6574  plz remind tmrw tht consult case wth periodontist
# 3574  today remind remind bhagyashree friends stay pune
# 151             please remind sql paper checking around
# 8381                                        remind hour
# 1551  remind check bank loans phone collect car docu...
# 1971                              thanks fr ur reminder

# %%
#Splitting the data in test and train with ratio of 10% and 90%
t_train , t_test , s_train , s_test = train_test_split(bow_train ,train_data['label_found'] , test_size = 0.10 , random_state=101)

# %% [markdown]
# # Logistic regression Machine Learning
#
#
# Logistic regression is a supervised learning classification algorithm used to predict the probability of a target variable. The nature of target or dependent variable is dichotomous, which means there would be only two possible classes. ... Mathematically, a logistic regression model predicts P(Y=1) as a function of X.

# %%
#Applying the Logistic regrssion
logreg = LogisticRegression()
logreg = logreg.fit(t_train, s_train)
# Out:
# C:\Users\JOY SINHA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#Print Accuracy
print(accuracy_score(logreg.predict(t_test),s_test))
# Out:
# 0.8116089613034623

# %% [markdown]
# # Random Forest Classifier
#
# Random forests or random decision forests are an ensemble learning method for classification, regression and other tasks that operate by constructing a multitude of decision trees at training time and outputting the class that is the mode of the classes or mean prediction of the individual trees.

# %%
#Applying Random Forest Classifier
rfc = RandomForestClassifier()
rfc.fit(t_train , s_train)
print(accuracy_score(rfc.predict(t_test),s_test))
# Out:
# 0.7352342158859471

# %% [markdown]
# # Decision Tree Classifier
#
#
# A decision tree classifier is a tree in which internal nodes are labeled by features. ... The classifier categorizes an object xi by recursively testing for the weights that the features labeling the internal nodes have in vector xi, until a leaf node is reached. The label of this node is then assigned to xi.

# %%
#Applying Decision Tree Classifier
dtc = DecisionTreeClassifier()
dtc.fit(t_train , s_train)
print(accuracy_score(s_test, dtc.predict(t_test)))
# Out:
# 0.7077393075356415

# %%
#Applying Logistic Regression
logreg = LogisticRegression()
logreg = logreg.fit(bow_train ,train_data['label_found'])
pred = logreg.predict(bow_test)
# Out:
# C:\Users\JOY SINHA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#Saving Model
filename = 'fmodel.sav'
joblib.dump(logreg, filename)

loaded_model = joblib.load(filename)

# %%
#Output Data in TSV format
output = pd.DataFrame( data={ "label_found":pred} )
output.to_csv( "result.tsv", index=False, quoting=3 )
output.sample(10)
# Out:
#     label_found
# 845       Found
# 779       Found
# 41        Found
# 769       Found
# 418       Found
# 597       Found
# 833   Not Found
# 361       Found
# 557       Found
# 894   Not Found
